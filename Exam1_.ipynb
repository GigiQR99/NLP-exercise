# %% [markdown]
# <a href="https://colab.research.google.com/github/GigiQR99/Exercise-Kye/blob/main/Exam1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exam 1
#
# ##Instructions
#
# You will be using 2 datasets that you should dowload form Canvas.
#
# * flights.csv
# * airports.csv
#
#  Flight dataset contains air transportation Statistics to track the on-time performance of domestic flights operated by large air carriers.
#
#  Airports contain additional information about these entities.

# %% [markdown]
# ##Needs to run for the files to be found
#
# At least you upload the files in the same folder as the notebook, run the 2 cells below to connect your Gdrive. Of course upload the files in your Gdrive and update the "path" in the cell below.

# %%
import os

# %%
#connect Gdrive to Colab
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Data Preparation Exercise

# %% [markdown]
# * **To Do:** Import Pandas, Numpy, Matplotlib and Seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import
import
import

# %% [markdown]
# **Exercise 1:** Read flights.csv
#
# Notes:
# * Upload the file to Colab. Same folder as this notebook is recommended

# %%
#From colab right window menu select the folder icon. Navigate through your folders until you find the file(s). Using the 3 vertical dots, select copy path. replace the variable path below
# with the path you just copied. Delete the name from the file of the path, but keep the last forwad slash. (Uncomment and update the path)
#if locally uploaded use the other (current) path variable.

#path = '/content/drive/.../'
path = '/content/'
file1 = 'flights.csv'
file2 = 'airports.csv'

# YOUR CODE HERE

# %%
#display some lines of you dataframe
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                  NaN               NaN
# 1           -9.0         0          0                  NaN               NaN
# 2            5.0         0          0                  NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# ...

# %% [markdown]
# **Exercise 2:** Calculate the Dataset rows and columns

# %%
#Your Code Here

# %% [markdown]
# **Exercise 3:** Dataframe Columns data types

# %%
#Your Code Here

# %% [markdown]
# **Exercise 4:** Summary Statistics for numerical and categorical variables

# %%
#Your Code Here

# %% [markdown]
# **Exercise 5:** Count column with the most blanks

# %%
#Your Code Here

# %% [markdown]
# **Exercise 6:** Delete a Column

# %%
# Delete the column with the most blanks

#Your Code Here

# %% [markdown]
# **Exercise 7:** Filtering Data

# %%
#How many Flights out of MIA

#Your Code Here

# %%
#How many destinations out of MIA

#Your Code Here

# %% [markdown]
# **Exercise 8:** Aggregating Data (Group by/Pivot)

# %%
# Top 3 destinations out of MIA

#Your Code Here

# %% [markdown]
# **Exercise 9:** Using graphs

# %%
plt.figure(figsize=(6, 10))

#Create a bar chart with the destinations out of MIA

# %% [markdown]
# **Exercise 10:** Univariate Anlysis
#
# Departure Delays distribution

# %%
# Out:
# <Axes: xlabel='DEPARTURE_DELAY', ylabel='Count'>

# %%
# Out:
# <Axes: xlabel='DEPARTURE_DELAY'>

# %% [markdown]
# Q10 Analysis of flights out of MIA by days of the week

# %%
# Out:
# <Axes: xlabel='DAY_OF_WEEK', ylabel='DEPARTURE_DELAY'>

# %% [markdown]
# **Exercise 11:** Multivariate Analysis (Correlation)
#
# If you execute this cell probably will fail. Can you fix it?

# %%
#Correlation index calculation
flightCorr = flights.corr()

# %%
plt.figure(figsize=(15, 12))  # Adjust the figure size if needed
sns.heatmap(flightCorr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Plot')
# Out:
# Text(0.5, 1.0, 'Correlation Plot')

# %% [markdown]
# * **Read the second File**
#
# Airports.csv

# %%
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919

# %% [markdown]
# **Exercise 12:** Merge both Files
#
# Find the matches (inner Join) between flights and merge by Destination_airport in flights and IATA_Code in airports

# %%
#Your Code Here
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AS            108      N309AS
# 2        2015      1    1            4      DL           1560      N3743H
# 3        2015      1    1            4      AS            130      N457AS
# 4        2015      1    1            4      AS            136      N431AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5332909  2015      9    4            5      B6            864      N198JB
# 5332910  2015      9    5            6      B6            864      N318JB
# 5332911  2015      9    6            7      B6            864      N183JB
# 5332912  2015      9    7            1      B6            864      N323JB
# 5332913  2015      9    8            2      B6            864      N373JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %% [markdown]
# **Exercise 13:** What states receive the most flights? What rank is Florida?
#  (Join/Group and Count)

# %%
#Agregate and Count

#Your Code Here

# %%
#Show it Graphically

#Your Code Here
plt.figure(figsize=(15, 12))

# %% [markdown]
# ##**THE END**
